# %%
pip install ipykernel
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string

# Download necessary NLTK resources
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
df = pd.read_csv('merged_files.csv', encoding='utf-8')
df.head()
# Out:
#        Just an advertisement for this cancer clinic.  \
# 0  MD Anderson treated my brother's rare bladder ...
# 1  Would x-rays pick up any cancer in the knee?  ...
# 2  My mom she has a 4 stage bone cancer is she go...
# 3  My father was diagnosed with bone cancer and I...
# 4                                              Ratio
#
#   I once had cancer virus 🦠 for over 10 years and I visited so many States in the United States 🇺🇸 seeking for help but it was all leading to spending of thousands of dollars until I was watching a YouTube series and I came across Dr. Emovon on YouTube ads and I decided to order his herbal medication and today I'm fully well from this problems. #dremovon..🙏🙏  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# ...

# %%
print(df.columns)
# Out:
# Index(['Just an advertisement for this cancer clinic.',
#        'I once had cancer virus 🦠 for over 10 years and I visited so many States in the United States 🇺🇸 seeking for help but it was all leading to spending of thousands of dollars until I was watching a YouTube series and I came across Dr. Emovon on YouTube ads and I decided to order his herbal medication and today I'm fully well from this problems. #dremovon..🙏🙏',
#        'have u guys some news',
#        'I have a biopsy Thursday and it’s really scary. Thank you for sharing your story ❤',
#        'Sadge',
#        'But in reality they are useless. Speaking from experience with 3 family members who had and fought cancer I can say that Macmillan did NOT give them any support. I would never give them a penny.',
#        'Lord God and angels is with you',
#        'Get your PSA tests done. Don't wait.',
#        'Dr Ozuka on YouTube has a permanent cure with his herbal medicine',
# ...

# %%
import pandas as pd
import re  
import string  

# Load the dataset
df = pd.read_csv('merged_files.csv')

# Define the cleaning function
def clean_text(text):
    # Convert text to lowercase
    text = text.lower()
    # Remove emojis and special unicode characters
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  
                               u"\U0001F300-\U0001F5FF"  
                               u"\U0001F680-\U0001F6FF"  
                               u"\U0001F1E0-\U0001F1FF"  
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               "]+", flags=re.UNICODE)
    text = emoji_pattern.sub(r'', text)
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Remove numbers
    text = re.sub(r'\d+', '', text)
    # Strip whitespace
    text = text.strip()
    return text

# Concatenate all text columns into one column and handle NaN values
df['combined_comment'] = df.fillna('').agg(lambda x: ' '.join(x.values.astype(str)), axis=1)

# Clean the combined text
df['combined_comment'] = df['combined_comment'].apply(clean_text)


df['data'] = df['combined_comment'].apply(lambda x: f"comment: {x}")


df_final = df[['data']].copy()

# Save to a new CSV file
df_final.to_csv('merged_files22.csv', index=False)


df_final.head()
# Out:
#                                                 data
# 0  comment: md anderson treated my brothers rare ...
# 1  comment: would xrays pick up any cancer in the...
# 2  comment: my mom she has a  stage bone cancer i...
# 3  comment: my father was diagnosed with bone can...
# 4                                     comment: ratio

# %%
print(df_final.columns)
# Out:
# Index(['data'], dtype='object')

# %%
df_final.shape
# Out:
# (4372, 1)

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Download NLTK resources
nltk.download('punkt')  # for word_tokenize
nltk.download('wordnet')  # for WordNetLemmatizer
nltk.download('stopwords')  # for stopwords

# Now you can define the lemmatizer
lemmatizer = WordNetLemmatizer()

# Tokenize each row in the text column
df_final['tokens'] = df_final['data'].apply(word_tokenize)

# Lemmatization and remove stopwords
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

def lemmatize_and_remove_stopwords(tokens):
    return [lemmatizer.lemmatize(token.lower(), pos='v') for token in tokens if token.isalpha() and token.lower() not in stop_words]

# Apply the function to the 'tokens' column
df_final['tokens'] = df_final['tokens'].apply(lemmatize_and_remove_stopwords)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
print(df_final)
# Out:
#                                                    data  \
# 0     comment: md anderson treated my brothers rare ...
# 1     comment: would xrays pick up any cancer in the...
# 2     comment: my mom she has a  stage bone cancer i...
# 3     comment: my father was diagnosed with bone can...
# 4                                        comment: ratio
# ...                                                 ...
# 4367           comment: nahhh she s strong she got this
# 4368  comment: wwww lfg ggez play for next hahahahah...
# 4369  comment: estoy transitando un problema de salu...
# 4370                      comment: i feel bad for tenz…
# 4371  comment: this video is giving me chills my gra...
#
#                                                  tokens
# 0     [comment, md, anderson, treat, brothers, rare,...
# 1     [comment, would, xrays, pick, cancer, knee, kn...
# 2     [comment, mom, stage, bone, cancer, go, surviv...
# 3     [comment, father, diagnose, bone, cancer, hone...
# ...

# %%
df_final.to_csv('tokenz.csv', index=False)

# %%
df_final.describe()
# Out:
#              data     tokens
# count        4372       4372
# unique       4060       3940
# top     comment:   [comment]
# freq          159        198

# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Make sure to download the stopwords from NLTK
nltk.download('stopwords')
nltk.download('punkt')

# Load the dataset
df_final = pd.read_csv('newfile.csv')  # Replace with your file path

# Define the function to remove stop words
def remove_stop_words(data):
    # Tokenize the text
    tokens = word_tokenize(data)
    # Filter out the stop words
    tokens = [word for word in tokens if not word.lower() in stopwords.words('english')]
    # Return the list of filtered tokens
    return tokens

# Apply the function to remove stop words from each row in the 'data' column
df_final['data'] = df_final['data'].apply(lambda x: ' '.join(remove_stop_words(x)))

# Save the DataFrame with the stop words removed to a new CSV file
df_final.to_csv('data_without_stopwords.csv', index=False)

# Check the first few entries
df_final.head()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#                                                 data  \
# 0  comment : md anderson treated brothers rare bl...
# 1  comment : would xrays pick cancer knee knee pa...
# 2  comment : mom stage bone cancer going survive ...
# 3  comment : father diagnosed bone cancer ’ hones...
# 4                                    comment : ratio
#
#                                               tokens
# 0  ['comment', 'md', 'anderson', 'treat', 'brothe...
# 1  ['comment', 'would', 'xrays', 'pick', 'cancer'...
# 2  ['comment', 'mom', 'stage', 'bone', 'cancer', ...
# 3  ['comment', 'father', 'diagnose', 'bone', 'can...
# ...

# %%
for word, count in value_counts.items():
    print(f"{word}: {count}")
# Out:
# comment:: 4372
# you: 3633
# and: 3219
# i: 2990
# the: 2526
# to: 2390
# a: 1943
# for: 1612
# my: 1461
# of: 1425
# is: 1323
# this: 1173
# cancer: 1097
# in: 1083
# so: 1070
# it: 1046
# are: 1036
# your: 1026
# that: 911
# with: 849
# was: 789
# have: 776
# he: 763
# on: 629
# me: 605
# from: 557
# all: 556
# be: 535
# but: 525
# god: 523
# will: 511
# she: 509
# strong: 496
# love: 457
# had: 441
# can: 417
# through: 415
# not: 387
# his: 369
# get: 368
# just: 366
# her: 354
# im: 335
# delia: 332
# dr: 329
# as: 322
# what: 314
# him: 311
# we: 308
# prayers: 298
# am: 293
# life: 291
# got: 290
# like: 287
# has: 281
# hope: 276
# now: 276
# bless: 275
# beautiful: 274
# do: 273
# or: 272
# know: 265
# they: 261
# at: 259
# thank: 258
# when: 254
# if: 245
# praying: 239
# much: 236
# very: 235
# an: 233
# years: 232
# out: 231
# how: 226
# going: 222
# there: 220
# about: 216
# no: 215
# who: 212
# good: 212
# chemo: 210
# also: 206
# been: 205
# its: 205
# up: 204
# ...

# %%
def clean_and_tokenize(data):
    # Lowercase the text
    data = data.lower()
    # Remove the word 'comment'
    data = data.replace('comment', '')
    # Tokenize the text
    tokens = word_tokenize(data)
    # Prepare a translation table to remove punctuation
    table = str.maketrans('', '', string.punctuation)
    # Remove stop words and punctuation
    stop_words_set = set(stopwords.words('english'))
    tokens = [word.translate(table) for word in tokens if word.isalpha() and word not in stop_words_set]
    # Return the list of filtered tokens
    return tokens

# Apply the function to each row in the 'data' column of the dataframe
df_final['tokens'] = df_final['data'].apply(clean_and_tokenize)

# Explode the 'tokens' lists into separate rows
df_exploded = df_final.explode('tokens')

# Save the tokenized data to a new CSV file, with each token on a separate row
df_exploded.to_csv('tokenized_data.csv', columns=['tokens'], index=False)

# Display the first few rows to verify the changes
df_exploded.head()
# Out:
#                                                 data    tokens
# 0  comment : md anderson treated brothers rare bl...        md
# 0  comment : md anderson treated brothers rare bl...  anderson
# 0  comment : md anderson treated brothers rare bl...   treated
# 0  comment : md anderson treated brothers rare bl...  brothers
# 0  comment : md anderson treated brothers rare bl...      rare

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction import text 

# Load the CSV file
file_path = 'tokenized_data.csv'  
data = pd.read_csv(file_path)

# Remove any NaN values in the data
data_cleaned = data.dropna()

# Define stop words. Adding custom stop words to the default English stop words list
additional_stop_words = ['like', 'just', 'said', 'think', 'know', 'people', 'time', 'year']
stop_words = list(text.ENGLISH_STOP_WORDS.union(additional_stop_words))

# Initializing the TfidfVectorizer with the custom stop words
vectorizer = TfidfVectorizer(stop_words=stop_words, use_idf=True)

# Applying TF-IDF transformation to the cleaned data
tfidf_matrix = vectorizer.fit_transform(data_cleaned['tokens'])

# Extract words and their corresponding TF-IDF scores
words = vectorizer.get_feature_names_out()
scores = tfidf_matrix.sum(axis=0).A1
tfidf_scores = pd.DataFrame(list(zip(words, scores)), columns=['Word', 'TF-IDF']).sort_values(by='TF-IDF', ascending=False)


# Display the top meaningful words
print(tfidf_scores.head(30))
# Out:
#            Word  TF-IDF
# 977      cancer  1099.0
# 2945        god   526.0
# 6831     strong   496.0
# 4275       love   457.0
# 3551         im   335.0
# 1720      delia   333.0
# 2000         dr   329.0
# 5499    prayers   298.0
# 2983        got   292.0
# 4139       life   291.0
# 3355       hope   276.0
# 757       bless   275.0
# 619   beautiful   274.0
# 7183      thank   258.0
# 5501    praying   239.0
# 8107      years   232.0
# 2954      going   222.0
# 2964       good   212.0
# 1150      chemo   210.0
# 3231       help   197.0
# 861      breast   192.0
# 3247     herbal   179.0
# 7422  treatment   178.0
# 6328    sending   170.0
# 692        best   162.0
# 3305        hiv   162.0
# 275     amazing   161.0
# 1944     doctor   161.0
# 5496       pray   160.0
# 1563       cure   155.0

# %%
from textblob import TextBlob
import pandas as pd

# Example words from your dataset
words = ['cancer', 'god', 'love', 'prayers', 'hope', 'beautiful', 'pray', 'cure']

# Create a DataFrame to store the results
sentiments = pd.DataFrame(columns=['Word', 'Polarity', 'Subjectivity'])

# Analyze the sentiment of each word
for word in words:
    blob = TextBlob(word)
    sentiment = blob.sentiment
    # Create a new DataFrame for the current word and its sentiments
    new_row = pd.DataFrame({'Word': [word], 'Polarity': [sentiment.polarity], 'Subjectivity': [sentiment.subjectivity]})
    # Concatenate the new DataFrame to the existing one
    sentiments = pd.concat([sentiments, new_row], ignore_index=True)

print(sentiments)
# Out:
#         Word  Polarity  Subjectivity
# 0     cancer      0.00           0.0
# 1        god      0.00           0.0
# 2       love      0.50           0.6
# 3    prayers      0.00           0.0
# 4       hope      0.00           0.0
# 5  beautiful      0.85           1.0
# 6       pray      0.00           0.0
# 7       cure      0.00           0.0
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8700\886024465.py:17: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   sentiments = pd.concat([sentiments, new_row], ignore_index=True)

# %%
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# Example words
words = ['cancer', 'god', 'love', 'prayers', 'hope', 'beautiful', 'pray', 'cure']

# Initialize VADER
analyzer = SentimentIntensityAnalyzer()

# Create a DataFrame to store the results
sentiments_vader = pd.DataFrame(columns=['Word', 'Negativity', 'Neutrality', 'Positivity', 'Compound'])

# Analyze the sentiment of each word
for word in words:
    vs = analyzer.polarity_scores(word)
    new_row = pd.DataFrame({
        'Word': [word],
        'Negativity': [vs['neg']],
        'Neutrality': [vs['neu']],
        'Positivity': [vs['pos']],
        'Compound': [vs['compound']]
    })
    # Concatenate the new row to the existing DataFrame
    sentiments_vader = pd.concat([sentiments_vader, new_row], ignore_index=True)

print(sentiments_vader)
# Out:
#         Word  Negativity  Neutrality  Positivity  Compound
# 0     cancer         1.0         0.0         0.0   -0.6597
# 1        god         0.0         0.0         1.0    0.2732
# 2       love         0.0         0.0         1.0    0.6369
# 3    prayers         0.0         1.0         0.0    0.0000
# 4       hope         0.0         0.0         1.0    0.4404
# 5  beautiful         0.0         0.0         1.0    0.5994
# 6       pray         0.0         0.0         1.0    0.3182
# 7       cure         0.0         1.0         0.0    0.0000
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_8700\1788702474.py:24: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
# ...

# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv('tokenized_data.csv')

# Display the column names
print(df.columns)

# Check if there's only one column in the DataFrame
if len(df.columns) == 1:
    # Assuming the only column contains the words
    words = df[df.columns[0]].tolist()
    negativity = []
    neutrality = []
    positivity = []
    compound = []
else:
    # Example words
    words = df[df.columns[0]].tolist()
    negativity = df[df.columns[1]].tolist()
    neutrality = df[df.columns[2]].tolist()
    positivity = df[df.columns[3]].tolist()
    compound = df[df.columns[4]].tolist()

# Display the example words
print(words)
print(negativity)
print(neutrality)
print(positivity)
print(compound)
# Out:
# Index(['tokens'], dtype='object')
# ...

# %%
from collections import Counter

# Read the text file
with open('tokens.txt', 'r', encoding='utf-8') as file:
    text = file.read()

# Tokenize the text into words
words = text.split()

# Count the occurrences of each word
word_counts = Counter(words)

# Print the total number of words and unique words
total_words = len(words)
unique_words = len(word_counts)
print("Total words:", total_words)
print("Unique words:", unique_words)

# Print each word and its frequency
for word, count in word_counts.items():
    print(word, ':', count)
# Out:
# Total words: 54440
# Unique words: 8490
# ['md', : 1
# 'anderson', : 7
# 'treated', : 11
# 'brothers', : 8
# 'rare', : 8
# 'bladder', : 11
# 'cancer', : 1099
# 'grateful', : 20
# 'hes', : 74
# 'fine', : 30
# 'years', : 232
# 'later', : 35
# 'would', : 147
# 'xrays', : 3
# 'pick', : 4
# 'knee', : 5
# 'pain', : 72
# 'cap', : 5
# 'went', : 104
# 'see', : 146
# 'top', : 14
# 'specialist', : 5
# 'denver', : 1
# 'didnt', : 58
# 'anything', : 30
# 'said', : 99
# 'keeps', : 8
# 'bothering', : 1
# 'come', : 78
# 'back', : 126
# 'sounds', : 10
# 'like', : 289
# 'scope', : 1
# 'sure', : 55
# 'mri', : 13
# 'show', : 34
# 'regular', : 3
# 'little', : 33
# 'arthritis', : 2
# 'bad', : 71
# 'mom', : 60
# 'stage', : 113
# 'bone', : 25
# 'going', : 222
# 'survive', : 18
# 'long', : 64
# 'father', : 44
# 'diagnosed', : 126
# 'honestly', : 11
# 'lost', : 54
# 'words', : 19
# 'right', : 66
# 'ratio', : 3
# 'try', : 32
# 'using', : 41
# 'iodine', : 1
# 'killed', : 7
# 'thumb', : 2
# 'nail', : 4
# ...

# %%
# Write word counts to a text file
with open('word_counts.txt', 'w', encoding='utf-8') as txtfile:
    for word, count in word_counts.items():
        txtfile.write(f'{word}: {count}\n')

# %%
import csv
import re
import nltk
from nltk.corpus import stopwords
from collections import Counter

# Download NLTK stopwords data
nltk.download('stopwords')

# Read the text file
with open('tokens.txt', 'r', encoding='utf-8') as file:
    text = file.read()


# Tokenize the text into words
words = nltk.word_tokenize(text)


# Remove stopwords
stop_words = set(stopwords.words('english'))
filtered_words = [word for word in words if word.lower() not in stop_words]

# Count the occurrences of each meaningful word
word_counts = Counter(filtered_words)

# Write word counts to a CSV file
with open('meaningful_word_counts.csv', 'w', newline='', encoding='utf-8') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Word', 'Count'])
    for word, count in word_counts.items():
        writer.writerow([word, count])
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from collections import Counter

with open("tokens.txt", "r", encoding='utf-8') as file:
    test = file.read()

# Tokenize text
tokens = word_tokenize(text.lower())  # tokenize and convert to lower case

# Remove stop words
stop_words = set(stopwords.words('english'))
tokens = [word for word in tokens if word not in stop_words]

# Optional: Remove low-information words based on frequency
word_freq = Counter(tokens)
min_frequency = 5  # threshold for word frequency
tokens = [word for word in tokens if word_freq[word] > min_frequency]

# Rejoin tokens into a single string
cleaned_text = ' '.join(tokens)

# Print to a CSV file
with open('cleaned_text.csv', 'w', newline='', encoding='utf-8') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(['Cleaned Text'])  
    csvwriter.writerow([cleaned_text])

# %%
word_freq = Counter(tokens)
with open('word_frequencies_full.csv', 'w', newline='', encoding='utf-8') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(['Word', 'Frequency'])  
    for word, freq in word_freq.items():
        csvwriter.writerow([word, freq])
